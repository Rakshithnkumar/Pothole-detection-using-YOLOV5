# %%
# !python detect.py --weights C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt --source ../jss1.jpeg --conf 0.4
# Out:
# Namespace(weights=['C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt'], source='../jss1.jpeg', img_size=640, conf_thres=0.4, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False)
# Fusing layers...
# image 1/1 C:\Users\yashw\Desktop\pothole1\jss1.jpeg: 640x384 2 potholes, Done. (0.342s)
# Results saved to runs\detect\exp35
# Using torch 1.11.0+cpu CPU
#
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# C:\Users\yashw\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Done. (0.519s)

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('C:/Users/yashw/Desktop/pothole1/yolov5/runs/detect/exp35/*.jpeg'):
    display(Image(filename=imageName))
    print("\n")

# %%
# !python train.py --resume
# Out:
# Resuming training from .\runs\train\yolov5s_results10\weights\last.pt
# Using torch 1.11.0+cpu CPU
#
# Namespace(weights='.\\runs\\train\\yolov5s_results10\\weights\\last.pt', cfg='', data='C:/Users/yashw/Desktop/pothole1/yolov5/data.yaml', hyp='data/hyp.scratch.yaml', epochs=200, batch_size=16, img_size=[416, 416], rect=False, resume=True, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=True, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, log_imgs=16, workers=8, project='runs/train', name='yolov5s_results', exist_ok=False, total_batch_size=16, world_size=1, global_rank=-1, save_dir='runs\\train\\yolov5s_results10')
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2022-06-15 17:54:51.290928: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# ...

# %%
model.save(pothole.h5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_900/3773412985.py in <module>
# ----> 1 model.save(pothole.h5)
#
# NameError: name 'model' is not defined

# %%
# !python detect.py --weights C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt --source ../jss.mp4 --conf 0.4
# Out:
# Namespace(weights=['C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt'], source='../jss.mp4', img_size=640, conf_thres=0.4, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False)
# Fusing layers...
# video 1/1 (1/160) C:\Users\yashw\Desktop\pothole1\jss.mp4: 640x352 3 potholes, Done. (0.188s)
# video 1/1 (2/160) C:\Users\yashw\Desktop\pothole1\jss.mp4: 640x352 3 potholes, Done. (0.123s)
# video 1/1 (3/160) C:\Users\yashw\Desktop\pothole1\jss.mp4: 640x352 2 potholes, Done. (0.142s)
# video 1/1 (4/160) C:\Users\yashw\Desktop\pothole1\jss.mp4: 640x352 2 potholes, Done. (0.135s)
# video 1/1 (5/160) C:\Users\yashw\Desktop\pothole1\jss.mp4: 640x352 2 potholes, Done. (0.182s)
# video 1/1 (6/160) C:\Users\yashw\Desktop\pothole1\jss.mp4: 640x352 2 potholes, Done. (0.177s)
# ...

# %%
import pickle

# %%
import torch

# %%
 model = torch.hub.load('C:/Users/yashw/Desktop/pothole1/yolov5', 'custom', path_or_model='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17456/1058794717.py in <module>
# ----> 1 model = torch.hub.load('C:/Users/yashw/Desktop/pothole1/yolov5', 'custom', path_or_model='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\hub.py in load(repo_or_dir, model, source, force_reload, verbose, skip_validation, *args, **kwargs)
#     400
#     401     if source == 'github':
# --> 402         repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, verbose, skip_validation)
#     403
#     404     model = _load_local(repo_or_dir, model, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\hub.py in _get_cache_or_reload(github, force_reload, verbose, skip_validation)
#     168         os.makedirs(hub_dir)
# ...

# %%
filename = "pathole_model"
pickle.dump(model,open(filename,wb))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17456/4231717837.py in <module>
#       1 filename = "pathole_model"
# ----> 2 pickle.dump(model,open(filename,wb))
#
# NameError: name 'model' is not defined

# %%
# !python detect.py --weights C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt --source 0 --conf 0.4

# %%
# !python train.py --resume
# Out:
# Resuming training from .\runs\train\yolov5s_results10\weights\last.pt
# Using torch 1.11.0+cpu CPU
#
# Namespace(weights='.\\runs\\train\\yolov5s_results10\\weights\\last.pt', cfg='', data='C:/Users/yashw/Desktop/pothole1/yolov5/data.yaml', hyp='data/hyp.scratch.yaml', epochs=200, batch_size=16, img_size=[416, 416], rect=False, resume=True, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=True, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, log_imgs=16, workers=8, project='runs/train', name='yolov5s_results', exist_ok=False, total_batch_size=16, world_size=1, global_rank=-1, save_dir='runs\\train\\yolov5s_results10')
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2022-06-15 13:17:30.208159: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# ...

# %%
model = torch.hub.load(repo_or_dir='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10', model='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/last.pt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17456/1411670547.py in <module>
# ----> 1 model = torch.hub.load(repo_or_dir='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10', model='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/last.pt')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\hub.py in load(repo_or_dir, model, source, force_reload, verbose, skip_validation, *args, **kwargs)
#     400
#     401     if source == 'github':
# --> 402         repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, verbose, skip_validation)
#     403
#     404     model = _load_local(repo_or_dir, model, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\hub.py in _get_cache_or_reload(github, force_reload, verbose, skip_validation)
# ...

# %%
torch.save(model.state_dict('C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10'), 'C:/Users/yashw/Desktop/pothole1/yolov5/pothole_model.p')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17456/1092847037.py in <module>
# ----> 1 torch.save(model.state_dict('C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10'), 'C:/Users/yashw/Desktop/pothole1/yolov5/pothole_model.pkl')
#
# NameError: name 'model' is not defined

# %%
import torch

# %%
model = torch.hub.load('C:/Users/yashw/Desktop/pothole1/yolov5','custom', path='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt',force_reload=True,source='local', pretrained = True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16872/1344979971.py in <module>
# ----> 1 model = torch.hub.load('C:/Users/yashw/Desktop/pothole1/yolov5','custom', path='C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt',force_reload=True,source='local', pretrained = True)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\hub.py in load(repo_or_dir, model, source, force_reload, verbose, skip_validation, *args, **kwargs)
#     402         repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, verbose, skip_validation)
#     403
# --> 404     model = _load_local(repo_or_dir, model, *args, **kwargs)
#     405     return model
#     406
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\hub.py in _load_local(hubconf_dir, model, *args, **kwargs)
# ...

# %%
import torch

# %%
torch.save(save_dir('C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt', pothole_model))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16192/3468599006.py in <module>
# ----> 1 torch.save(save_dir('C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt', pothole_model))
#
# NameError: name 'save_dir' is not defined

# %%
torch.save('C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16192/3282991028.py in <module>
# ----> 1 torch.save('C:/Users/yashw/Desktop/pothole1/yolov5/runs/train/yolov5s_results10/weights/best.pt')
#
# TypeError: save() missing 1 required positional argument: 'f'

# %%
import os
os.system("detect.py source=")
# Out:
# 0
